# %% [markdown]
# # Create idiom lexicon with scraped definitions

# %%
from bs4 import BeautifulSoup
import requests 
import re
import pandas as pd
from tqdm import tqdm

# %%
# read in SLIDE idiom lexicon
idiom_lexicon = pd.read_csv('idiomLexicon.tsv', sep='\t')
idiom_lexicon
# Out:
#                   Idiom                                     WiktionaryURL
# 0        American Dream     https://en.wiktionary.org/wiki/American_Dream  \
# 1              Catch-22           https://en.wiktionary.org/wiki/Catch-22
# 2     Christmas present  https://en.wiktionary.org/wiki/Christmas_present
# 3        Downing Street     https://en.wiktionary.org/wiki/Downing_Street
# 4         Dutch courage      https://en.wiktionary.org/wiki/Dutch_courage
# ...                 ...                                               ...
# 4995           your man           https://en.wiktionary.org/wiki/your_man
# 4996        yours truly        https://en.wiktionary.org/wiki/yours_truly
# 4997         zero in on         https://en.wiktionary.org/wiki/zero_in_on
# 4998           zero-day           https://en.wiktionary.org/wiki/zero-day
# 4999             zip up             https://en.wiktionary.org/wiki/zip_up
#
#       Pos  Neg  Neu  Inapprop.  Total  %Pos  %Neg  %Neu Maj. Label
# 0       8    0    2          0     10   0.8   0.0   0.2   positive  \
# 1       0    7    3          0     10   0.0   0.7   0.3   negative
# 2       6    0    4          0     10   0.6   0.0   0.4   positive
# 3       0    0   10          0     10   0.0   0.0   1.0    neutral
# 4       2    2    6          0     10   0.2   0.2   0.6    neutral
# ...   ...  ...  ...        ...    ...   ...   ...   ...        ...
# 4995    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4996    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4997    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4998    0    4    6          0     10   0.0   0.4   0.6    neutral
# 4999    0    1    9          0     10   0.0   0.1   0.9    neutral
#
#      FilterOut(X)
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4995          NaN
# 4996          NaN
# 4997          NaN
# 4998          NaN
# 4999          NaN
#
# [5000 rows x 12 columns]

# %% [markdown]
# ## Scrape definitions from Wiktionary

# %%
# for i, row in idiom_lexicon.iterrows():  # for testing, because tqdm does overrides prints
for i, row in tqdm(idiom_lexicon.iterrows(), total=len(idiom_lexicon)):
    # if row['definition'] != 'nan':
    #     continue
    # print(row['Idiom'], end=': ')
    url = row['WiktionaryURL'] #'https://en.wiktionary.org/wiki/Oreo_cookie'
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')

    sections = soup.find_all('span', {'class': 'ib-content'}) #mw-content-text > div.mw-parser-output > ol > li:nth-child(1) > span.ib-content > a
    # get all sections that include 'idiomatic'
    idiomatic_sections = [section for section in sections if 'idiomatic' in section.text]
    # print(idiomatic_sections)

    # get text of parent section of each idiomatic section, using only first text found
    texts = [section.find_parent().text for section in idiomatic_sections]
    texts = [text.split('\n')[0] for text in texts]
    # remove (idiomatic) from text
    texts = [re.sub(r'\(.*idiomatic.*\) ', '', text) for text in texts]
    # concatenate all found definitions
    texts = ' '.join(texts)
    # print(texts)
    # print('---')

    # add to dataframe
    idiom_lexicon.at[i, 'definition'] = texts

    # save
    idiom_lexicon.to_csv('idiom_lexicon_scraped.csv', index=False)
    # break
# Out:
# 100%|██████████| 5000/5000 [46:06<00:00,  1.81it/s]

# %%
idiom_lexicon[(idiom_lexicon.definition.isna()) & (idiom_lexicon.idiom_id <= 2029)]
# Out:
#                           Idiom
# 2             Christmas present  \
# 3                Downing Street
# 12    Great Britain and Ireland
# 26                     John Doe
# 29                  John Thomas
# ...                         ...
# 2439             labour of love
# 2441       ladies and gentlemen
# 2449           larger than life
# 2455                 last trump
# 2459               late bloomer
#
#                                           WiktionaryURL  Pos  Neg  Neu
# 2      https://en.wiktionary.org/wiki/Christmas_present    6    0    4  \
# 3         https://en.wiktionary.org/wiki/Downing_Street    0    0   10
# 12    https://en.wiktionary.org/wiki/Great_Britain_a...    1    0    9
# 26              https://en.wiktionary.org/wiki/John_Doe    0    0   10
# 29           https://en.wiktionary.org/wiki/John_Thomas    0    0    6
# ...                                                 ...  ...  ...  ...
# 2439      https://en.wiktionary.org/wiki/labour_of_love    5    2    3
# 2441  https://en.wiktionary.org/wiki/ladies_and_gent...    0    0   10
# 2449    https://en.wiktionary.org/wiki/larger_than_life    7    1    2
# 2455          https://en.wiktionary.org/wiki/last_trump    0    0   10
# 2459        https://en.wiktionary.org/wiki/late_bloomer    2    3    5
#
#       Inapprop.  Total  %Pos  %Neg  %Neu Maj. Label FilterOut(X) definition
# 2             0     10   0.6   0.0   0.4   positive          NaN        NaN  \
# 3             0     10   0.0   0.0   1.0    neutral          NaN        NaN
# 12            0     10   0.1   0.0   0.9    neutral          NaN        NaN
# 26            0     10   0.0   0.0   1.0    neutral          NaN        NaN
# 29            4     10   0.0   0.0   0.6    neutral          NaN        NaN
# ...         ...    ...   ...   ...   ...        ...          ...        ...
# 2439          0     10   0.5   0.2   0.3   positive          NaN        NaN
# 2441          0     10   0.0   0.0   1.0    neutral          NaN        NaN
# 2449          0     10   0.7   0.1   0.2   positive          NaN        NaN
# 2455          0     10   0.0   0.0   1.0    neutral          NaN        NaN
# 2459          0     10   0.2   0.3   0.5    neutral          NaN        NaN
#
#      sentiment idiom_id
# 2     positive        2
# 3        other        3
# 12       other        9
# 26       other       20
# 29       other       21
# ...        ...      ...
# 2439  positive     2010
# 2441     other     2012
# 2449  positive     2018
# 2455     other     2023
# 2459     other     2027
#
# [476 rows x 15 columns]

# %% [markdown]
# ## Create sentiment column

# %%
idiom_lexicon = pd.read_csv('idiom_lexicon_scraped.csv')
idiom_lexicon.rename(columns={'Maj. Label': 'sentiment'}, inplace=True)

sentiment_map = {
    'positive': 'positive',
    'negative': 'negative',
    'neutral': 'other'
}

idiom_lexicon['sentiment'] = idiom_lexicon['sentiment'].map(sentiment_map)
print(idiom_lexicon['sentiment'].value_counts())
idiom_lexicon.to_csv('idiom_lexicon_scraped.csv', index=False)
idiom_lexicon
# Out:
# sentiment
# other       2945
# negative    1108
# positive     946
# Name: count, dtype: int64

# %% [markdown]
# ## Adding idiom ids

# %%
idiom_lexicon = pd.read_csv('idiom_lexicon_scraped.csv')
idiom_lexicon['idiom_id'] = pd.NA
dataset = pd.read_csv('../Sentence Generation/Datasets/full_dataset.csv', index_col=0)
# drop non unique idioms
dataset = dataset.drop_duplicates(subset=['idiom'])
dataset
# Out:
#        idiom_id              idiom
# 0             0     American Dream  \
# 5             1           Catch-22
# 10            2  Christmas present
# 15            3     Downing Street
# 20            4      Dutch courage
# ...         ...                ...
# 10125      2025         last-ditch
# 10130      2026         latch onto
# 10135      2027       late bloomer
# 10140      2028         late model
# 10145      2029     laughing stock
#
#                                                 sentence      emotion
# 0      Sally finally achieved the American Dream, liv...    Happiness
# 5      Stuck in this bureaucratic mess feels like a C...      Anxiety
# 10     Every year, my aunt surprises us with unexpect...     Surprise
# 15     The new employee quickly found his way to Down...   Admiration
# 20     After a few shots of Dutch courage, he finally...   Excitement
# ...                                                  ...          ...
# 10125  In a last-ditch effort to save their marriage,...         Hope
# 10130  She quickly latched onto the idea of a weekend...   Excitement
# 10135  Despite being a late bloomer, she eventually s...        Pride
# 10140  I just bought a late model car, and I can't hi...    Happiness
# 10145  They made me the laughing stock of the whole o...  Humiliation
#
# [2030 rows x 4 columns]

# %%
# match idioms in dataset to idioms in idiom lexicon
for i, row in tqdm(dataset.iterrows(), total=len(dataset)):
    idiom = row['idiom']
    # find idiom in idiom lexicon
    idiom_lexicon_row = idiom_lexicon[idiom_lexicon['Idiom'] == idiom].index
    if len(idiom_lexicon_row) == 0:
        continue
    idiom_lexicon_row = idiom_lexicon_row[0]
    idiom_lexicon.at[idiom_lexicon_row, 'idiom_id'] = row['idiom_id']

idiom_lexicon.to_csv('idiom_lexicon_scraped.csv', index=False)
idiom_lexicon
# Out:
# 100%|██████████| 2030/2030 [00:00<00:00, 2600.09it/s]
#                   Idiom                                     WiktionaryURL
# 0        American Dream     https://en.wiktionary.org/wiki/American_Dream  \
# 1              Catch-22           https://en.wiktionary.org/wiki/Catch-22
# 2     Christmas present  https://en.wiktionary.org/wiki/Christmas_present
# 3        Downing Street     https://en.wiktionary.org/wiki/Downing_Street
# 4         Dutch courage      https://en.wiktionary.org/wiki/Dutch_courage
# ...                 ...                                               ...
# 4995           your man           https://en.wiktionary.org/wiki/your_man
# 4996        yours truly        https://en.wiktionary.org/wiki/yours_truly
# 4997         zero in on         https://en.wiktionary.org/wiki/zero_in_on
# 4998           zero-day           https://en.wiktionary.org/wiki/zero-day
# 4999             zip up             https://en.wiktionary.org/wiki/zip_up
#
#       Pos  Neg  Neu  Inapprop.  Total  %Pos  %Neg  %Neu Maj. Label
# 0       8    0    2          0     10   0.8   0.0   0.2   positive  \
# 1       0    7    3          0     10   0.0   0.7   0.3   negative
# 2       6    0    4          0     10   0.6   0.0   0.4   positive
# 3       0    0   10          0     10   0.0   0.0   1.0    neutral
# 4       2    2    6          0     10   0.2   0.2   0.6    neutral
# ...   ...  ...  ...        ...    ...   ...   ...   ...        ...
# 4995    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4996    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4997    1    0    9          0     10   0.1   0.0   0.9    neutral
# 4998    0    4    6          0     10   0.0   0.4   0.6    neutral
# 4999    0    1    9          0     10   0.0   0.1   0.9    neutral
#
#      FilterOut(X)                                         definition
# 0             NaN  A widespread determination by Americans to pro...  \
# 1             NaN  A difficult situation from which there is no e...
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN  The courage or bravado induced by alcohol. An ...
# ...           ...                                                ...
# 4995          NaN                                                NaN
# 4996          NaN  Used to close a note or letter. I, me, or myself.
# 4997          NaN                                  To converge (on).
# 4998          NaN  newly discovered, and therefore still not fixe...
# 4999          NaN                To close as if with a zip fastener.
#
#      sentiment idiom_id
# 0     positive        0
# 1     negative        1
# 2     positive        2
# 3        other        3
# 4        other        4
# ...        ...      ...
# 4995     other      NaN
# 4996     other      NaN
# 4997     other      NaN
# 4998     other      NaN
# 4999     other      NaN
#
# [5000 rows x 15 columns]

# %% [markdown]
# ## (Scraping evaluation)

# %%
import pandas as pd
idiom_lexicon = pd.read_csv('idiom_lexicon_scraped.csv')

idiom_lexicon['definition'].isna().sum()
# Out:
# 1168

# %%
len(idiom_lexicon)
# Out:
# 5000

# %%
idiom_lexicon[idiom_lexicon['Idiom'] == 'jot down']
# Out:
#          Idiom                            WiktionaryURL  Pos  Neg  Neu
# 2325  jot down  https://en.wiktionary.org/wiki/jot_down    0    0   10  \
#
#       Inapprop.  Total  %Pos  %Neg  %Neu Maj. Label FilterOut(X)
# 2325          0     10   0.0   0.0   1.0    neutral          NaN  \
#
#                                       definition sentiment
# 2325  to write down hurriedly; to make a note of     other
